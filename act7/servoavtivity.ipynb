# %%
pip install pyserial
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: C:\Users\erinx\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import serial
import time

SERIAL_PORT = 'COM6'
BAUD_RATE = 9600

arduino = serial.Serial(port=SERIAL_PORT, baudrate=BAUD_RATE, timeout=0.1)
time.sleep(2)

print("Connected to Arduino")
print("Type 'exit' to stop")

while True:
    user_input = input("Enter angle (0-180): ")

    if user_input.lower() == "exit":
        break

    try:
        angle = int(user_input)

        if 0 <= angle <= 180:
            arduino.write(f"{angle}\n".encode())

            time.sleep(0.1)
            while arduino.in_waiting:
                print(arduino.readline().decode().strip())

        else:
            print("Error: Invalid Angle. Please enter a value between 0 and 180.")

    except ValueError:
        print("Error: Please enter a valid number.")

arduino.close()
# Out:
# Connected to Arduino
# Type 'exit' to stop
# Arduino is ready to receive angles (0-180).
# Servo moved to: 180
# Servo moved to: 0
# Servo moved to: 150
# Servo moved to: 0
# Servo moved to: 120
# Error: Invalid Angle. Please enter a value between 0 and 180.
